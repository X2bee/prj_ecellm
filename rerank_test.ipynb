# %%
import requests

url = f"https://fo.x2bee.com/api/goods/v1/search/product?searchWord=산행도구&ctgNo=&from=0&size=30&sortField=&sort=&filters=&special="
response = requests.get(url)

# %%
response.json()['payload']['searchDataList']
# Out:
# [{'id': '1_11506035',
#   'goodsNo': '11506035',
#   'goodsNm': '트레일러닝베스트 아웃도어 마라톤 등산용품 러닝 여자조끼 등산조끼 (10000.00)',
#   'prestNm': None,
#   'adveWrd': None,
#   'schKwdNm': ['트레일러닝베스트,아웃도어,마라톤,등산용품,러닝,여자조끼,등산조끼'],
#   'brandNo': '10283',
#   'brandNm': '플샵',
#   'buyrAgeLmtCd': '0',
#   'goodsRegDtm': None,
#   'saleStatCd': '10',
#   'deliProcTypCd': '20',
#   'deliWayCd': '01',
#   'deliDday': '3',
#   'rcntSalePrc': '52880',
#   'salePrc': 42300,
#   'aplyPrc': 42300,
#   'dcRate': 20,
#   'dispCtgNo': [{'dispCtgNo': '2551',
#     'ctgFullPath': '2547>2538>2551',
#     'ctgFullPathNm': '패션의류/잡화>남성패션>의류',
#     'siteNo': '1',
#     'siteNm': '플래티어',
#     'dpmlNo': '10001',
#     'lrgCtgNm': '패션의류/잡화',
#     'lrgCtgNo': '2547'}],
#   'dlexTypCd': '30',
#   'payWayMeanCd': '11,12,32',
#   'rservSaleYn': 'N',
#   'goodsRevCnt': 0,
#   'goodsRevHlpfulCnt': 0,
#   'goodsRevStarscrAvgVal': 0,
#   'wishListCnt': '0',
#   'goodsDtlDesc': None,
#   'sendGb': 'A',
#   'langCd': 'ko',
# ...
